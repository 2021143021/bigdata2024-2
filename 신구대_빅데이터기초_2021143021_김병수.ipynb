# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_excel('/content/drive/MyDrive/등록인구.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     동별(1)  동별(2) 2022 4/4 2022 4/4.1 2022 4/4.2 2022 4/4.3 2022 4/4.4  \
# 0   동별(1)  동별(2)  세대 (세대)      계 (명)      계 (명)      계 (명)    한국인 (명)
# 1   동별(1)  동별(2)       소계         소계         남자         여자         소계
# 2      합계     소계  4446296    9667669    4675560    4992109    9428372
# 3     NaN    종로구    72524     152211      72980      79231     141379
# 4     NaN     중구    63139     130785      63377      67408     120437
# 5     NaN    용산구   109805     233284     113012     120272     218650
# 6     NaN    성동구   133305     288234     139691     148543     281000
# 7     NaN    광진구   169291     351252     168197     183055     337416
# 8     NaN   동대문구   169873     353601     171903     181698     336644
# ...

# %%
df_gu = pd.read_excel('/content/drive/MyDrive/등록인구.xlsx', skiprows=[0,3])
df_gu
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     동별(1)  동별(2) 세대 (세대)   계 (명) 계 (명).1 계 (명).2 한국인 (명) 한국인 (명).1 한국인 (명).2  \
# 0   동별(1)  동별(2)      소계      소계      남자      여자      소계        남자        여자
# 1     NaN    종로구   72524  152211   72980   79231  141379     68395     72984
# 2     NaN     중구   63139  130785   63377   67408  120437     58563     61874
# 3     NaN    용산구  109805  233284  113012  120272  218650    105087    113563
# 4     NaN    성동구  133305  288234  139691  148543  281000    136633    144367
# 5     NaN    광진구  169291  351252  168197  183055  337416    162541    174875
# 6     NaN   동대문구  169873  353601  171903  181698  336644    165755    170889
# 7     NaN    중랑구  187413  390140  191422  198718  385318    189537    195781
# ...

# %%
df_seoul_gu = df_gu[['동별(2)', '계 (명)']]
df_seoul_gu
# Out:
#     동별(2)   계 (명)
# 0   동별(2)      소계
# 1     종로구  152211
# 2      중구  130785
# 3     용산구  233284
# 4     성동구  288234
# 5     광진구  351252
# 6    동대문구  353601
# 7     중랑구  390140
# 8     성북구  441984
# 9     강북구  297702
# 10    도봉구  313989
# 11    노원구  508014
# 12    은평구  470602
# 13   서대문구  319554
# 14    마포구  375585
# 15    양천구  444010
# 16    강서구  574638
# 17    구로구  418418
# 18    금천구  242818
# 19   영등포구  398085
# 20    동작구  390432
# 21    관악구  501226
# 22    서초구  408451
# 23    강남구  534103
# 24    송파구  664514
# 25    강동구  464037

# %%
df_seoul_gu.columns = ['시군구명', '인구수']
df_seoul_gu
# Out:
#      시군구명     인구수
# 0   동별(2)      소계
# 1     종로구  152211
# 2      중구  130785
# 3     용산구  233284
# 4     성동구  288234
# 5     광진구  351252
# 6    동대문구  353601
# 7     중랑구  390140
# 8     성북구  441984
# 9     강북구  297702
# 10    도봉구  313989
# 11    노원구  508014
# 12    은평구  470602
# 13   서대문구  319554
# 14    마포구  375585
# 15    양천구  444010
# 16    강서구  574638
# 17    구로구  418418
# 18    금천구  242818
# 19   영등포구  398085
# 20    동작구  390432
# 21    관악구  501226
# 22    서초구  408451
# 23    강남구  534103
# 24    송파구  664514
# 25    강동구  464037

# %%
df_seoul_gu.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   시군구명    26 non-null     object
#  1   인구수     26 non-null     object
# dtypes: object(2)
# memory usage: 544.0+ bytes

# %%
df_seoul_gu = df_seoul_gu.set_index('시군구명', drop=True) # 시각화를 위해 시군구명을 인덱스로 내린다
df_seoul_gu
# Out:
#           인구수
# 시군구명
# 동별(2)      소계
# 종로구    152211
# 중구     130785
# 용산구    233284
# 성동구    288234
# 광진구    351252
# 동대문구   353601
# 중랑구    390140
# 성북구    441984
# 강북구    297702
# 도봉구    313989
# 노원구    508014
# 은평구    470602
# 서대문구   319554
# 마포구    375585
# 양천구    444010
# 강서구    574638
# 구로구    418418
# 금천구    242818
# 영등포구   398085
# 동작구    390432
# 관악구    501226
# 서초구    408451
# 강남구    534103
# 송파구    664514
# 강동구    464037

# %%
# 인구수를 숫자형으로 변환
df_seoul_gu['인구수'] = pd.to_numeric(df_seoul_gu['인구수'], errors='coerce')

# NaN 값 처리 (선택사항)
df_seoul_gu['인구수'] = df_seoul_gu['인구수'].fillna(0)

# 인구수를 기준으로 내림차순 정렬
df_seoul_gu_sorted = df_seoul_gu.sort_values(by='인구수', ascending=False)

# 정렬된 데이터 출력
df_seoul_gu_sorted
# Out:
#             인구수
# 시군구명
# 송파구    664514.0
# 강서구    574638.0
# 강남구    534103.0
# 노원구    508014.0
# 관악구    501226.0
# 은평구    470602.0
# 강동구    464037.0
# 양천구    444010.0
# 성북구    441984.0
# 구로구    418418.0
# 서초구    408451.0
# 영등포구   398085.0
# 동작구    390432.0
# 중랑구    390140.0
# 마포구    375585.0
# 동대문구   353601.0
# 광진구    351252.0
# 서대문구   319554.0
# 도봉구    313989.0
# 강북구    297702.0
# 성동구    288234.0
# 금천구    242818.0
# 용산구    233284.0
# 종로구    152211.0
# 중구     130785.0
# 동별(2)       0.0

# %%
import os

# 폴더가 존재하지 않으면 생성
if not os.path.exists('data'):
    os.makedirs('data')

# 파일 저장
df_seoul_gu.to_csv('./data/df_seoul_gu.csv', index=False)

# %%
df_seoul_gu.to_csv('./data/df_seoul_gu.csv')

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 33.2 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib
import matplotlib.pyplot as plt
plt.rc('font', family='NanumGothic')  # 나눔 고딕 폰트 설정

df_seoul_gu.sort_values(by='인구수').plot(kind='barh', color='tab:blue', figsize=(12,8))
plt.title('서울시 구별 인구수 순위')
# Out:
# Text(0.5, 1.0, '서울시 구별 인구수 순위')

# %%
pd.read_csv('/content/drive/MyDrive/음식물류+폐기물+발생량+및+처리현황.csv')
# Out:
#     자치구별(1)  자치구별(2)    2022 2022.1 2022.2  2022.3  2022.4 2022.5 2022.6  \
# 0   자치구별(1)  자치구별(2)     발생량    발생량    발생량     발생량     발생량    발생량    발생량
# 1   자치구별(1)  자치구별(2)      소계   처리방법   처리방법    처리방법    처리방법   처리방법   처리방법
# 2   자치구별(1)  자치구별(2)      소계     매립     소각     재활용     재활용    재활용    재활용
# 3   자치구별(1)  자치구별(2)      소계     소계     소계      소계     사료화    퇴비화   하수병합
# 4       서울시       소계  2497.7      -      -  2497.7  1418.9  897.4      -
# 5       서울시      종로구    75.5      -      -    75.5    63.6   11.1      -
# 6       서울시       중구    90.6      -      -    90.6    33.8   56.0      -
# 7       서울시      용산구    64.9      -      -    64.9    54.8    9.1      -
# 8       서울시      성동구    76.6      -      -    76.6    37.4   38.3      -
# 9       서울시      광진구    83.3      -      -    83.3    53.9   29.0      -
# 10      서울시     동대문구    85.6      -      -    85.6     7.5    0.2      -
# 11      서울시      중랑구    83.5      -      -    83.5    24.5   58.1      -
# ...

# %%
df_tr = pd.read_csv('/content/drive/MyDrive/음식물류+폐기물+발생량+및+처리현황.csv', skiprows=[0,5])
df_tr
# Out:
#     자치구별(1)  자치구별(2)    발생량 발생량.1 발생량.2  발생량.3  발생량.4 발생량.5 발생량.6 발생량.7
# 0   자치구별(1)  자치구별(2)     소계  처리방법  처리방법   처리방법   처리방법  처리방법  처리방법  처리방법
# 1   자치구별(1)  자치구별(2)     소계    매립    소각    재활용    재활용   재활용   재활용   재활용
# 2   자치구별(1)  자치구별(2)     소계    소계    소계     소계    사료화   퇴비화  하수병합    기타
# 3       서울시      종로구   75.5     -     -   75.5   63.6  11.1     -   0.8
# 4       서울시       중구   90.6     -     -   90.6   33.8  56.0     -   0.8
# 5       서울시      용산구   64.9     -     -   64.9   54.8   9.1     -   0.9
# 6       서울시      성동구   76.6     -     -   76.6   37.4  38.3     -   0.9
# 7       서울시      광진구   83.3     -     -   83.3   53.9  29.0     -   0.4
# 8       서울시     동대문구   85.6     -     -   85.6    7.5   0.2     -  77.8
# 9       서울시      중랑구   83.5     -     -   83.5   24.5  58.1     -   0.9
# 10      서울시      성북구   91.9     -     -   91.9    3.4  88.5     -     -
# 11      서울시      강북구   63.2     -     -   63.2    2.3  60.3     -   0.5
# ...

# %%
df_tr.groupby(['자치구별(2)'])['발생량'].sum().sort_values(ascending=False)
# Out:
# 자치구별(2)
# 자치구별(2)    소계소계소계
# 관악구          92.5
# 성북구          91.9
# 중구           90.6
# 양천구          90.0
# 동대문구         85.6
# 중랑구          83.5
# 광진구          83.3
# 마포구          81.0
# 동작구          80.6
# 구로구          77.4
# 성동구          76.6
# 은평구          75.7
# 종로구          75.5
# 도봉구          71.8
# 용산구          64.9
# 강북구          63.2
# 서대문구         63.1
# 금천구          55.2
# 강남구         245.4
# 송파구         212.8
# 서초구         144.5
# 영등포구        134.8
# 강서구         128.7
# 노원구         116.2
# 강동구         113.1
# Name: 발생량, dtype: object

# %%
df_tr['발생량'] = pd.to_numeric(df_tr['발생량'], errors='coerce')

# %%
df_tr['발생량'] = df_tr['발생량'].fillna(0)

# %%
df_tr_22 = df_tr.groupby(['자치구별(2)'])['발생량'].sum().sort_values()[-20:]
df_tr_22.plot(kind='barh', color='lightgray', figsize=(12, 8))
plt.title('서울시 구별 쓰레기배출 총량 상위 20')
plt.show()

# %%
df_tr.groupby(['자치구별(2)'])['발생량'].mean().sort_values(ascending=False)
# Out:
# 자치구별(2)
# 강남구        245.4
# 송파구        212.8
# 서초구        144.5
# 영등포구       134.8
# 강서구        128.7
# 노원구        116.2
# 강동구        113.1
# 관악구         92.5
# 성북구         91.9
# 중구          90.6
# 양천구         90.0
# 동대문구        85.6
# 중랑구         83.5
# 광진구         83.3
# 마포구         81.0
# 동작구         80.6
# 구로구         77.4
# 성동구         76.6
# 은평구         75.7
# 종로구         75.5
# 도봉구         71.8
# 용산구         64.9
# 강북구         63.2
# 서대문구        63.1
# 금천구         55.2
# 자치구별(2)      0.0
# Name: 발생량, dtype: float64

# %%
df_tr_seoul_22_mean = df_tr.groupby(['자치구별(2)'])['발생량'].mean().sort_values()[-20:]

df_tr_seoul_22_mean.plot(kind='barh', color='rosybrown', figsize=(12,8))
plt.title("서울시 구별 쓰레기배출 평균 상위 20")
# Out:
# Text(0.5, 1.0, '서울시 구별 쓰레기배출 평균 상위 20')

# %%
df_food_seoul = pd.read_csv('/content/drive/MyDrive/식품위생업현황.csv')
df_food_seoul
# Out:
#     자치구별(1)  자치구별(2)    2023  2023.1 2023.2  2023.3 2023.4 2023.5 2023.6  \
# 0   자치구별(1)  자치구별(2)      합계   식품접객업  식품접객업   식품접객업  식품접객업  식품접객업  식품접객업
# 1   자치구별(1)  자치구별(2)      소계      소계  휴게음식점   일반음식점    제과점   단란주점   유흥주점
# 2   자치구별(1)  자치구별(2)      소계      소계     소계      소계     소계     소계     소계
# 3        합계       소계  234526  167853  37094  121928   3906   1966   1719
# 4        합계      종로구   11656    9503   1761    7247    136    103    187
# 5        합계       중구   11066    8715   2204    5995    153     60    213
# 6        합계      용산구    7411    5357   1001    4151    102     42     17
# 7        합계      성동구    7458    5322   1067    4034    132     34     22
# 8        합계      광진구    7193    5357   1192    3942    111     70     11
# 9        합계     동대문구    8666    5793   1219    4315    115     67     53
# 10       합계      중랑구    6952    5090    999    3857    104     92     17
# 11       합계      성북구    7340    5577   1353    4001    123     47      8
# ...

# %%
df_food_seoul = pd.read_csv('/content/drive/MyDrive/식품위생업현황.csv', skiprows=[0,4])
df_food_seoul
# Out:
#     자치구별(1)  자치구별(2)     합계  식품접객업 식품접객업.1 식품접객업.2 식품접객업.3 식품접객업.4 식품접객업.5  \
# 0   자치구별(1)  자치구별(2)     소계     소계   휴게음식점   일반음식점     제과점    단란주점    유흥주점
# 1   자치구별(1)  자치구별(2)     소계     소계      소계      소계      소계      소계      소계
# 2        합계      종로구  11656   9503    1761    7247     136     103     187
# 3        합계       중구  11066   8715    2204    5995     153      60     213
# 4        합계      용산구   7411   5357    1001    4151     102      42      17
# 5        합계      성동구   7458   5322    1067    4034     132      34      22
# 6        합계      광진구   7193   5357    1192    3942     111      70      11
# 7        합계     동대문구   8666   5793    1219    4315     115      67      53
# 8        합계      중랑구   6952   5090     999    3857     104      92      17
# 9        합계      성북구   7340   5577    1353    4001     123      47       8
# 10       합계      강북구   6105   4473     774    3442      82      87      65
# ...

# %%
df_food_seoul.groupby(['자치구별(2)'])['합계'].sum().sort_values(ascending=False)
# Out:
# 자치구별(2)
# 자치구별(2)     소계소계
# 관악구         8982
# 동대문구        8666
# 강동구         8566
# 노원구         8199
# 구로구         7619
# 성동구         7458
# 용산구         7411
# 성북구         7340
# 광진구         7193
# 은평구         7121
# 중랑구         6952
# 서대문구        6597
# 양천구         6497
# 동작구         6357
# 금천구         6199
# 강북구         6105
# 도봉구         4754
# 강남구        20200
# 송파구        15892
# 마포구        14555
# 서초구        13425
# 영등포구       13346
# 강서구        12370
# 종로구        11656
# 중구         11066
# Name: 합계, dtype: object

# %%
df_food_seoul = df_food_seoul.rename(columns={'합계': '음식점수'})
df_food_seoul
# Out:
#     자치구별(1)  자치구별(2)   음식점수  식품접객업 식품접객업.1 식품접객업.2 식품접객업.3 식품접객업.4 식품접객업.5  \
# 0   자치구별(1)  자치구별(2)     소계     소계   휴게음식점   일반음식점     제과점    단란주점    유흥주점
# 1   자치구별(1)  자치구별(2)     소계     소계      소계      소계      소계      소계      소계
# 2        합계      종로구  11656   9503    1761    7247     136     103     187
# 3        합계       중구  11066   8715    2204    5995     153      60     213
# 4        합계      용산구   7411   5357    1001    4151     102      42      17
# 5        합계      성동구   7458   5322    1067    4034     132      34      22
# 6        합계      광진구   7193   5357    1192    3942     111      70      11
# 7        합계     동대문구   8666   5793    1219    4315     115      67      53
# 8        합계      중랑구   6952   5090     999    3857     104      92      17
# 9        합계      성북구   7340   5577    1353    4001     123      47       8
# 10       합계      강북구   6105   4473     774    3442      82      87      65
# ...

# %%
df_food_seoul_t = df_food_seoul.groupby(['자치구별(2)'])['음식점수'].sum().sort_values(ascending=False)
df_food_seoul_t
# Out:
# 자치구별(2)
# 자치구별(2)     소계소계
# 관악구         8982
# 동대문구        8666
# 강동구         8566
# 노원구         8199
# 구로구         7619
# 성동구         7458
# 용산구         7411
# 성북구         7340
# 광진구         7193
# 은평구         7121
# 중랑구         6952
# 서대문구        6597
# 양천구         6497
# 동작구         6357
# 금천구         6199
# 강북구         6105
# 도봉구         4754
# 강남구        20200
# 송파구        15892
# 마포구        14555
# 서초구        13425
# 영등포구       13346
# 강서구        12370
# 종로구        11656
# 중구         11066
# Name: 음식점수, dtype: object

# %%
df_tr_seoul_t = df_tr.groupby(['자치구별(2)'])['발생량'].sum().sort_values(ascending=False)
df_tr_seoul_t
# Out:
# 자치구별(2)
# 강남구        245.4
# 송파구        212.8
# 서초구        144.5
# 영등포구       134.8
# 강서구        128.7
# 노원구        116.2
# 강동구        113.1
# 관악구         92.5
# 성북구         91.9
# 중구          90.6
# 양천구         90.0
# 동대문구        85.6
# 중랑구         83.5
# 광진구         83.3
# 마포구         81.0
# 동작구         80.6
# 구로구         77.4
# 성동구         76.6
# 은평구         75.7
# 종로구         75.5
# 도봉구         71.8
# 용산구         64.9
# 강북구         63.2
# 서대문구        63.1
# 금천구         55.2
# 자치구별(2)      0.0
# Name: 발생량, dtype: float64

# %%
df_food_sum = pd.merge(df_food_seoul_t, df_tr_seoul_t, on='자치구별(2)')

# %%
df_food_seoul_t = df_food_seoul_t.reset_index()
df_tr_seoul_t = df_tr_seoul_t.reset_index()
df_food_sum = pd.merge(df_food_seoul_t, df_tr_seoul_t, left_index=True, right_index=True)

# %%
df_food_sum = pd.merge(df_food_seoul_t, df_tr_seoul_t, left_index=True, right_index=True)
df_food_sum = pd.merge(df_food_seoul_t,df_tr_seoul_t)
df_food_sum
# Out:
#     자치구별(2)   음식점수    발생량
# 0   자치구별(2)   소계소계    0.0
# 1       관악구   8982   92.5
# 2      동대문구   8666   85.6
# 3       강동구   8566  113.1
# 4       노원구   8199  116.2
# 5       구로구   7619   77.4
# 6       성동구   7458   76.6
# 7       용산구   7411   64.9
# 8       성북구   7340   91.9
# 9       광진구   7193   83.3
# 10      은평구   7121   75.7
# 11      중랑구   6952   83.5
# 12     서대문구   6597   63.1
# 13      양천구   6497   90.0
# 14      동작구   6357   80.6
# 15      금천구   6199   55.2
# 16      강북구   6105   63.2
# 17      도봉구   4754   71.8
# 18      강남구  20200  245.4
# 19      송파구  15892  212.8
# 20      마포구  14555   81.0
# 21      서초구  13425  144.5
# 22     영등포구  13346  134.8
# 23      강서구  12370  128.7
# 24      종로구  11656   75.5
# 25       중구  11066   90.6

# %%
df_food_sum.describe()
# Out:
#               발생량
# count   26.000000
# mean    96.073077
# std     48.463748
# min      0.000000
# 25%     75.550000
# 50%     83.400000
# 75%    107.950000
# max    245.400000

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='발생량', y='음식점수', hue='자치구별(2)', data=df_food_sum)

# 각 점 위에 구 이름 표시
for i in range(len(df_food_sum)):
    x_val = df_food_sum.iloc[i]['발생량']
    y_val = df_food_sum.iloc[i]['음식점수']
    gu_name = df_food_sum.iloc[i]['자치구별(2)']
    plt.text(x_val + 0.5,  # 살짝 오른쪽으로 이동
             y_val,
             gu_name,
             fontsize=9)


plt.title('구별 음식점수와 음식물 쓰레기 배출량의 관계')
plt.show()

# %%
df_seoul_gu = df_gu[['동별(2)', '계 (명)']]
df_seoul_gu
# Out:
#     동별(2)   계 (명)
# 0   동별(2)      소계
# 1     종로구  152211
# 2      중구  130785
# 3     용산구  233284
# 4     성동구  288234
# 5     광진구  351252
# 6    동대문구  353601
# 7     중랑구  390140
# 8     성북구  441984
# 9     강북구  297702
# 10    도봉구  313989
# 11    노원구  508014
# 12    은평구  470602
# 13   서대문구  319554
# 14    마포구  375585
# 15    양천구  444010
# 16    강서구  574638
# 17    구로구  418418
# 18    금천구  242818
# 19   영등포구  398085
# 20    동작구  390432
# 21    관악구  501226
# 22    서초구  408451
# 23    강남구  534103
# 24    송파구  664514
# 25    강동구  464037

# %%
df_seoul_gu.columns = ['자치구별(2)', '인구수']
df_seoul_gu
# Out:
#    자치구별(2)     인구수
# 0    동별(2)      소계
# 1      종로구  152211
# 2       중구  130785
# 3      용산구  233284
# 4      성동구  288234
# 5      광진구  351252
# 6     동대문구  353601
# 7      중랑구  390140
# 8      성북구  441984
# 9      강북구  297702
# 10     도봉구  313989
# 11     노원구  508014
# 12     은평구  470602
# 13    서대문구  319554
# 14     마포구  375585
# 15     양천구  444010
# 16     강서구  574638
# 17     구로구  418418
# 18     금천구  242818
# 19    영등포구  398085
# 20     동작구  390432
# 21     관악구  501226
# 22     서초구  408451
# 23     강남구  534103
# 24     송파구  664514
# 25     강동구  464037

# %%
# '인구수' 칼럼을 숫자형으로 변환 (문자열이 있을 경우 NaN으로 변환됨)
df_seoul_gu['인구수'] = pd.to_numeric(df_seoul_gu['인구수'], errors='coerce')

# NaN 값을 포함한 행 제거
df_seoul_gu = df_seoul_gu.dropna(subset=['인구수'])

# 인구수 기준으로 내림차순 정렬
df_seoul_gu_t = df_seoul_gu.groupby(['자치구별(2)'])['인구수'].sum().sort_values(ascending=False)

# 결과 확인
print(df_seoul_gu_t)
# Out:
# 자치구별(2)
# 송파구     664514.0
# 강서구     574638.0
# 강남구     534103.0
# 노원구     508014.0
# 관악구     501226.0
# 은평구     470602.0
# 강동구     464037.0
# 양천구     444010.0
# 성북구     441984.0
# 구로구     418418.0
# 서초구     408451.0
# 영등포구    398085.0
# 동작구     390432.0
# 중랑구     390140.0
# 마포구     375585.0
# 동대문구    353601.0
# 광진구     351252.0
# 서대문구    319554.0
# 도봉구     313989.0
# 강북구     297702.0
# 성동구     288234.0
# 금천구     242818.0
# 용산구     233284.0
# 종로구     152211.0
# 중구      130785.0
# Name: 인구수, dtype: float64
# <ipython-input-62-1f56f69b1eac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_seoul_gu['인구수'] = pd.to_numeric(df_seoul_gu['인구수'], errors='coerce')

# %%
df_seoul_gu_t = df_seoul_gu.groupby(['자치구별(2)'])['인구수'].sum().sort_values(ascending=False)
df_seoul_gu_t
# Out:
# 자치구별(2)
# 송파구     664514.0
# 강서구     574638.0
# 강남구     534103.0
# 노원구     508014.0
# 관악구     501226.0
# 은평구     470602.0
# 강동구     464037.0
# 양천구     444010.0
# 성북구     441984.0
# 구로구     418418.0
# 서초구     408451.0
# 영등포구    398085.0
# 동작구     390432.0
# 중랑구     390140.0
# 마포구     375585.0
# 동대문구    353601.0
# 광진구     351252.0
# 서대문구    319554.0
# 도봉구     313989.0
# 강북구     297702.0
# 성동구     288234.0
# 금천구     242818.0
# 용산구     233284.0
# 종로구     152211.0
# 중구      130785.0
# Name: 인구수, dtype: float64

# %%
# Population DataFrame: Extracting only the required columns for 구별 and 인구수
population_df_cleaned = population_df.iloc[3:, [1, 3]]  # Selecting the 구별 and total population columns
population_df_cleaned.columns = ['구별', '등록인구수']
population_df_cleaned.reset_index(drop=True, inplace=True)

# Food Hygiene DataFrame: Extracting 구별 and 음식점 수 (식품접객업 소계)
food_hygiene_df_cleaned = food_hygiene_df.iloc[3:, [1, 3]]  # Selecting the 구별 and 식품접객업 소계 columns
food_hygiene_df_cleaned.columns = ['구별', '음식점수']
food_hygiene_df_cleaned.reset_index(drop=True, inplace=True)

# Food Waste DataFrame: Extracting 구별 and 음식물 쓰레기 배출량 (2022 발생량 소계)
food_waste_df_cleaned = food_waste_df.iloc[4:, [1, 2]]  # Selecting the 구별 and 발생량 소계 columns
food_waste_df_cleaned.columns = ['구별', '음식물쓰레기배출량']
food_waste_df_cleaned.reset_index(drop=True, inplace=True)

# Convert data types to numeric where applicable
population_df_cleaned['등록인구수'] = pd.to_numeric(population_df_cleaned['등록인구수'], errors='coerce')
food_hygiene_df_cleaned['음식점수'] = pd.to_numeric(food_hygiene_df_cleaned['음식점수'], errors='coerce')
food_waste_df_cleaned['음식물쓰레기배출량'] = pd.to_numeric(food_waste_df_cleaned['음식물쓰레기배출량'], errors='coerce')

# Merge all three dataframes on the '구별' column
merged_df = pd.merge(population_df_cleaned, food_hygiene_df_cleaned, on='구별')
merged_df = pd.merge(merged_df, food_waste_df_cleaned, on='구별')

# Display the cleaned and merged dataframe
print(merged_df.head())  # Display first few rows of merged dataframe

# Setting up the figure size for better readability
plt.figure(figsize=(18, 6))

# Scatter plot for 등록인구수 vs 음식점수
plt.subplot(1, 3, 1)
sns.regplot(data=merged_df, x='등록인구수', y='음식점수')
plt.title('구별 등록인구수 vs 음식점수')
plt.xlabel('등록인구수')
plt.ylabel('음식점수')

# Scatter plot for 음식점수 vs 음식물쓰레기배출량
plt.subplot(1, 3, 2)
sns.regplot(data=merged_df, x='음식점수', y='음식물쓰레기배출량')
plt.title('구별 음식점수 vs 음식물쓰레기배출량')
plt.xlabel('음식점수')
plt.ylabel('음식물쓰레기배출량')

# Pairwise scatter plot with correlation matrix for all three variables
plt.subplot(1, 3, 3)

# Select only numeric columns for correlation
numeric_columns = merged_df[['등록인구수', '음식점수', '음식물쓰레기배출량']]
sns.heatmap(numeric_columns.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('등록인구수, 음식점수, 음식물쓰레기배출량 상관관계')



plt.tight_layout()
plt.show()
# Out:
#     구별   등록인구수  음식점수  음식물쓰레기배출량
# 0  종로구  152211  9503       75.5
# 1   중구  130785  8715       90.6
# 2  용산구  233284  5357       64.9
# 3  성동구  288234  5322       76.6
# 4  광진구  351252  5357       83.3

# %%
population_df = pd.read_excel('/content/drive/MyDrive/등록인구.xlsx')
food_hygiene_df = pd.read_csv('/content/drive/MyDrive/식품위생업현황.csv', encoding='utf-8')
food_waste_df = pd.read_csv('/content/drive/MyDrive/음식물류+폐기물+발생량+및+처리현황.csv', encoding='utf-8')


# Merge all three dataframes on the '구별' column
merged_df = pd.merge(population_df_cleaned, food_hygiene_df_cleaned, on='구별')
merged_df = pd.merge(merged_df, food_waste_df_cleaned, on='구별')

# Display the cleaned and merged dataframe
print(merged_df.head())  # Display first few rows of merged dataframe

# Setting up the figure size for better readability
plt.figure(figsize=(10, 6))

# Bubble plot for 등록인구수 vs 음식점수
# Using 점의 크기 to represent 등록인구수 for better visualization
plt.scatter(merged_df['등록인구수'], merged_df['음식점수'], s=merged_df['등록인구수'] * 0.01, alpha=0.5, color='green')
plt.title('구별 등록인구수 vs 음식점수 버블 차트')
plt.xlabel('등록인구수')
plt.ylabel('음식점수')
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     구별   등록인구수  음식점수  음식물쓰레기배출량
# 0  종로구  152211  9503       75.5
# 1   중구  130785  8715       90.6
# 2  용산구  233284  5357       64.9
# 3  성동구  288234  5322       76.6
# 4  광진구  351252  5357       83.3

# %%
# Bar plot for 음식점수 vs 음식물쓰레기배출량
sns.barplot(data=merged_df, x='음식점수', y='음식물쓰레기배출량', palette='viridis')
plt.title('음식점수 vs 음식물쓰레기배출량 막대그래프')
plt.xlabel('음식점수')
plt.ylabel('음식물쓰레기배출량')
plt.xticks(rotation=45)
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-66-fa4e3d18b2bd>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=merged_df, x='음식점수', y='음식물쓰레기배출량', palette='viridis')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib  # 한글 폰트 설정을 위해 추가
import matplotlib

# Set Korean font
plt.rc('font', family='NanumGothic')  # 나눔 고딕 폰트 설정
matplotlib.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# Load the uploaded files
population_df = pd.read_excel('/content/drive/MyDrive/등록인구.xlsx')
food_hygiene_df = pd.read_csv('/content/drive/MyDrive/식품위생업현황.csv', encoding='utf-8')
food_waste_df = pd.read_csv('/content/drive/MyDrive/음식물류+폐기물+발생량+및+처리현황.csv', encoding='utf-8')

# Extract relevant columns from each dataframe for merging and analysis
# Population DataFrame: Extracting only the required columns for 구별 and 인구수
population_df_cleaned = population_df.iloc[3:, [1, 3]]  # Selecting the 구별 and total population columns
population_df_cleaned.columns = ['구별', '등록인구수']
population_df_cleaned.reset_index(drop=True, inplace=True)

# Food Hygiene DataFrame: Extracting 구별 and 음식점 수 (식품접객업 소계)
food_hygiene_df_cleaned = food_hygiene_df.iloc[3:, [1, 3]]  # Selecting the 구별 and 식품접객업 소계 columns
food_hygiene_df_cleaned.columns = ['구별', '음식점수']
food_hygiene_df_cleaned.reset_index(drop=True, inplace=True)

# Food Waste DataFrame: Extracting 구별 and 음식물 쓰레기 배출량 (2022 발생량 소계)
food_waste_df_cleaned = food_waste_df.iloc[4:, [1, 2]]  # Selecting the 구별 and 발생량 소계 columns
food_waste_df_cleaned.columns = ['구별', '음식물쓰레기배출량']
food_waste_df_cleaned.reset_index(drop=True, inplace=True)

# Convert data types to numeric where applicable
population_df_cleaned['등록인구수'] = pd.to_numeric(population_df_cleaned['등록인구수'], errors='coerce')
food_hygiene_df_cleaned['음식점수'] = pd.to_numeric(food_hygiene_df_cleaned['음식점수'], errors='coerce')
food_waste_df_cleaned['음식물쓰레기배출량'] = pd.to_numeric(food_waste_df_cleaned['음식물쓰레기배출량'], errors='coerce')

# Merge all three dataframes on the '구별' column
merged_df = pd.merge(population_df_cleaned, food_hygiene_df_cleaned, on='구별')
merged_df = pd.merge(merged_df, food_waste_df_cleaned, on='구별')

# Sort the data for better visualization
sorted_df = merged_df.sort_values(by='등록인구수', ascending=False)

# Extract sorted data for plotting
sorted_districts = sorted_df['구별'].tolist()
sorted_population_values = sorted_df['등록인구수'].tolist()
sorted_trash_values = sorted_df['음식물쓰레기배출량'].tolist()

# Scatter plot for 등록인구수 vs 음식물쓰레기배출량
plt.figure(figsize=(12, 8))

# 산점도
plt.scatter(sorted_population_values, sorted_trash_values, color='blue', alpha=0.7)

# 도시 이름 레이블 추가
for i, district in enumerate(sorted_districts):
    plt.text(sorted_population_values[i], sorted_trash_values[i], district, fontsize=9, ha='right', va='bottom')

# 축 레이블과 제목 설정
plt.xlabel('총인구수')
plt.ylabel('음식물 쓰레기 배출량 (톤)')
plt.title('서울시 총인구수와 음식물 쓰레기 배출량의 관계')

# 그래프 출력
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib  # 한글 폰트 설정을 위해 추가
import matplotlib

# Set Korean font
plt.rc('font', family='NanumGothic')  # 나눔 고딕 폰트 설정
matplotlib.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# Load the uploaded files
population_df = pd.read_excel('/content/drive/MyDrive/등록인구.xlsx')
food_hygiene_df = pd.read_csv('/content/drive/MyDrive/식품위생업현황.csv', encoding='utf-8')
food_waste_df = pd.read_csv('/content/drive/MyDrive/음식물류+폐기물+발생량+및+처리현황.csv', encoding='utf-8')

# Extract relevant columns from each dataframe for merging and analysis

# Population DataFrame: Extracting only the required columns for 구별 and 인구수
population_df_cleaned = population_df.iloc[3:, [1, 3]]  # Selecting the 구별 and total population columns
population_df_cleaned.columns = ['구별', '등록인구수']
population_df_cleaned.reset_index(drop=True, inplace=True)

# Food Hygiene DataFrame: Extracting 구별 and 음식점 수 (식품접객업 소계)
food_hygiene_df_cleaned = food_hygiene_df.iloc[3:, [1, 3]]  # Selecting the 구별 and 식품접객업 소계 columns
food_hygiene_df_cleaned.columns = ['구별', '음식점수']
food_hygiene_df_cleaned.reset_index(drop=True, inplace=True)

# Food Waste DataFrame: Extracting 구별 and 음식물 쓰레기 배출량 (2022 발생량 소계)
food_waste_df_cleaned = food_waste_df.iloc[4:, [1, 2]]  # Selecting the 구별 and 발생량 소계 columns
food_waste_df_cleaned.columns = ['구별', '음식물쓰레기배출량']
food_waste_df_cleaned.reset_index(drop=True, inplace=True)

# Convert data types to numeric where applicable
population_df_cleaned['등록인구수'] = pd.to_numeric(population_df_cleaned['등록인구수'], errors='coerce')
food_hygiene_df_cleaned['음식점수'] = pd.to_numeric(food_hygiene_df_cleaned['음식점수'], errors='coerce')
food_waste_df_cleaned['음식물쓰레기배출량'] = pd.to_numeric(food_waste_df_cleaned['음식물쓰레기배출량'], errors='coerce')

# Merge all three dataframes on the '구별' column
merged_df = pd.merge(population_df_cleaned, food_hygiene_df_cleaned, on='구별')
merged_df = pd.merge(merged_df, food_waste_df_cleaned, on='구별')

# Sort the data for better visualization
sorted_df = merged_df.sort_values(by='등록인구수', ascending=False)

# Extract sorted data for plotting
sorted_districts = sorted_df['구별'].tolist()
sorted_population_values = sorted_df['등록인구수'].tolist()
sorted_food_values = sorted_df['음식점수'].tolist()

# Scatter plot for 등록인구수 vs 음식점수
plt.figure(figsize=(12, 8))

# 산점도
plt.scatter(sorted_population_values, sorted_food_values, color='green', alpha=0.7)

# 도시 이름 레이블 추가
for i, district in enumerate(sorted_districts):
    plt.text(sorted_population_values[i], sorted_food_values[i], district, fontsize=9, ha='right', va='bottom')

# 축 레이블과 제목 설정
plt.xlabel('총인구수')
plt.ylabel('음식점수')
plt.title('서울시 총인구수와 음식점수의 관계')

# 그래프 출력
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib  # 한글 폰트 설정을 위해 추가
import matplotlib

# Set Korean font
plt.rc('font', family='NanumGothic')  # 나눔 고딕 폰트 설정
matplotlib.rcParams['axes.unicode_minus'] = False  # 마이너스 기호 깨짐 방지

# Load the uploaded files
population_df = pd.read_excel('/content/drive/MyDrive/등록인구.xlsx')
food_hygiene_df = pd.read_csv('/content/drive/MyDrive/식품위생업현황.csv', encoding='utf-8')
food_waste_df = pd.read_csv('/content/drive/MyDrive/음식물류+폐기물+발생량+및+처리현황.csv', encoding='utf-8')

# Extract relevant columns from each dataframe for merging and analysis

# Population DataFrame: Extracting only the required columns for 구별 and 인구수
population_df_cleaned = population_df.iloc[3:, [1, 3]]  # Selecting the 구별 and total population columns
population_df_cleaned.columns = ['구별', '등록인구수']
population_df_cleaned.reset_index(drop=True, inplace=True)

# Food Hygiene DataFrame: Extracting 구별 and 음식점 수 (식품접객업 소계)
food_hygiene_df_cleaned = food_hygiene_df.iloc[3:, [1, 3]]  # Selecting the 구별 and 식품접객업 소계 columns
food_hygiene_df_cleaned.columns = ['구별', '음식점수']
food_hygiene_df_cleaned.reset_index(drop=True, inplace=True)

# Food Waste DataFrame: Extracting 구별 and 음식물 쓰레기 배출량 (2022 발생량 소계)
food_waste_df_cleaned = food_waste_df.iloc[4:, [1, 2]]  # Selecting the 구별 and 발생량 소계 columns
food_waste_df_cleaned.columns = ['구별', '음식물쓰레기배출량']
food_waste_df_cleaned.reset_index(drop=True, inplace=True)

# Convert data types to numeric where applicable
population_df_cleaned['등록인구수'] = pd.to_numeric(population_df_cleaned['등록인구수'], errors='coerce')
food_hygiene_df_cleaned['음식점수'] = pd.to_numeric(food_hygiene_df_cleaned['음식점수'], errors='coerce')
food_waste_df_cleaned['음식물쓰레기배출량'] = pd.to_numeric(food_waste_df_cleaned['음식물쓰레기배출량'], errors='coerce')

# Merge all three dataframes on the '구별' column
merged_df = pd.merge(population_df_cleaned, food_hygiene_df_cleaned, on='구별')
merged_df = pd.merge(merged_df, food_waste_df_cleaned, on='구별')

# Sort the data for better visualization (음식점 수를 기준으로 정렬)
sorted_df = merged_df.sort_values(by='음식점수', ascending=False)

# Extract sorted data for plotting
sorted_districts = sorted_df['구별'].tolist()
sorted_restaurant_values = sorted_df['음식점수'].tolist()
sorted_trash_values = sorted_df['음식물쓰레기배출량'].tolist()

# Scatter plot for 음식점수 vs 음식물쓰레기배출량
plt.figure(figsize=(12, 8))

# 산점도
plt.scatter(sorted_restaurant_values, sorted_trash_values, color='green', alpha=0.7)

# 도시 이름 레이블 추가
for i, district in enumerate(sorted_districts):
    plt.text(sorted_restaurant_values[i], sorted_trash_values[i], district, fontsize=9, ha='right', va='bottom')

# 축 레이블과 제목 설정
plt.xlabel('총 음식점 수')
plt.ylabel('음식물 쓰레기 배출량 (톤)')
plt.title('서울시 총 음식점 수와 음식물 쓰레기 배출량의 관계')

# 그래프 출력
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the uploaded files
population_df = pd.read_excel('/content/drive/MyDrive/등록인구.xlsx')
food_hygiene_df = pd.read_csv('/content/drive/MyDrive/식품위생업현황.csv', encoding='utf-8')
food_waste_df = pd.read_csv('/content/drive/MyDrive/음식물류+폐기물+발생량+및+처리현황.csv', encoding='utf-8')

# Extract relevant columns from each dataframe for merging and analysis

# Population DataFrame: Extracting only the required columns for 구별 and 인구수
population_df_cleaned = population_df.iloc[3:, [1, 3]]  # Selecting the 구별 and total population columns
population_df_cleaned.columns = ['구별', '등록인구수']
population_df_cleaned.reset_index(drop=True, inplace=True)

# Food Hygiene DataFrame: Extracting 구별 and 음식점 수 (식품접객업 소계)
food_hygiene_df_cleaned = food_hygiene_df.iloc[3:, [1, 3]]  # Selecting the 구별 and 식품접객업 소계 columns
food_hygiene_df_cleaned.columns = ['구별', '음식점수']
food_hygiene_df_cleaned.reset_index(drop=True, inplace=True)

# Food Waste DataFrame: Extracting 구별 and 음식물 쓰레기 배출량 (2022 발생량 소계)
food_waste_df_cleaned = food_waste_df.iloc[4:, [1, 2]]  # Selecting the 구별 and 발생량 소계 columns
food_waste_df_cleaned.columns = ['구별', '음식물쓰레기배출량']
food_waste_df_cleaned.reset_index(drop=True, inplace=True)

# Convert data types to numeric where applicable
population_df_cleaned['등록인구수'] = pd.to_numeric(population_df_cleaned['등록인구수'], errors='coerce')
food_hygiene_df_cleaned['음식점수'] = pd.to_numeric(food_hygiene_df_cleaned['음식점수'], errors='coerce')
food_waste_df_cleaned['음식물쓰레기배출량'] = pd.to_numeric(food_waste_df_cleaned['음식물쓰레기배출량'], errors='coerce')

# Merge all three dataframes on the '구별' column
merged_df = pd.merge(population_df_cleaned, food_hygiene_df_cleaned, on='구별')
merged_df = pd.merge(merged_df, food_waste_df_cleaned, on='구별')

# Display the cleaned and merged dataframe
print(merged_df.head())  # Display first few rows of merged dataframe

# Pairplot to visualize relationships between 등록인구수, 음식점수, and 음식물쓰레기배출량
sns.pairplot(merged_df[['등록인구수', '음식점수', '음식물쓰레기배출량']], diag_kind='kde', plot_kws={'alpha': 0.6})
plt.suptitle('등록인구수, 음식점수, 음식물쓰레기배출량 간의 관계 - 산점도 행렬', y=1.02)
plt.show()

# Correlation table to show relationships between 등록인구수, 음식점수, and 음식물쓰레기배출량
corr_matrix = merged_df[['등록인구수', '음식점수', '음식물쓰레기배출량']].corr()
print("상관계수 테이블:")
print(corr_matrix)
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:237: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#     구별   등록인구수  음식점수  음식물쓰레기배출량
# 0  종로구  152211  9503       75.5
# 1   중구  130785  8715       90.6
# 2  용산구  233284  5357       64.9
# 3  성동구  288234  5322       76.6
# 4  광진구  351252  5357       83.3
# 상관계수 테이블:
#               등록인구수      음식점수  음식물쓰레기배출량
# 등록인구수      1.000000  0.265322   0.654260
# 음식점수       0.265322  1.000000   0.762518
# 음식물쓰레기배출량  0.654260  0.762518   1.000000
